# %%
# sample = pd.read_csv('Data/train/303_P/303_CLNF_features.txt')
# sample = pd.read_csv('Data/train/303_P/303_CLNF_AUs.txt')
# sample = pd.read_csv('Data/train/303_P/303_CLNF_features3D.txt')
# sample = pd.read_csv('Data/train/303_P/303_CLNF_gaze.txt')
# sample = pd.read_pickle('Data/train/303_P/303_CLNF_hog.bin')
# sample = pd.read_csv('Data/train/303_P/303_CLNF_pose.txt')
